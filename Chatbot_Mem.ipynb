# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanav2102/LangChain-AgenticAI/blob/main/Chatbot_Mem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Installing the packages
#
# !pip install -qU langchain-google-genai google-generativeai==0.8.5

# %%
import os
from google.colab import userdata
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain.chains import LLMChain

#for memeory
from langchain.memory import ConversationalBufferMemory

# %%
#SETTING GEMINI API KEY
os.environ["GOOGLE_API_KEY"] = userdata.get("GEMINI_API_KEY")

# %%
# Recommend for demos -> fast and economial model is gemini 2.0 flash
model_name = "gemini-2.0-flash"

# llm instance
llm = ChatGoogleGenerativeAI(model=model_name,
                             convert_system_message_to_human =True,#to mkae it predictable with langchain
                             temperature = 0.7 )#to encorage creativity and responses
print(f"Ready with model: {model_name}")

# %%
memory = ConversationalBufferMemory(
    memory_key="chat_history",
    input_key
    return_messages=True
)
